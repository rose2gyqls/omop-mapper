# %%
import pandas as pd

syn = pd.read_csv('/home/work/skku/hyo/MapOMOP/data/CONCEPT_SYNONYM.csv', sep='\t')
syn.head()
# Out:
#    concept_id                               concept_synonym_name  \
# 0     3019950  CELL MARKERS; Immune globulin A; Immunoglobuli...
# 1     3019950                          Lymphs IgA/lymph NFr Spec
# 2     3019951  Finding; Findings; nursing; Ordinal; Point in ...
# 3     3019955                          pCO2 Bld Postductal TcCo2
# 4     3019955  Bld Postductal; Bld.foot; BldA.foot; Blood; Ca...
#
#    language_concept_id
# 0              4180186
# 1              4180186
# 2              4180186
# 3              4180186
# 4              4180186

# %%
concept = pd.read_csv('/home/work/skku/hyo/MapOMOP/data/CONCEPT.csv', sep='\t')
concept.head()
# Out:
# /tmp/ipykernel_1050536/1353796791.py:1: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   concept = pd.read_csv('/home/work/skku/hyo/MapOMOP/data/CONCEPT.csv', sep='\t')
#    concept_id                             concept_name domain_id  \
# 0    45756805                     Pediatric Cardiology  Provider
# 1    45756804                 Pediatric Anesthesiology  Provider
# 2    45756803  Pathology-Anatomic / Pathology-Clinical  Provider
# 3    45756802                    Pathology - Pediatric  Provider
# 4    45756801            Pathology - Molecular Genetic  Provider
#
#   vocabulary_id     concept_class_id standard_concept concept_code  \
# 0          ABMS  Physician Specialty                S  OMOP4821938
# 1          ABMS  Physician Specialty                S  OMOP4821939
# 2          ABMS  Physician Specialty                S  OMOP4821940
# 3          ABMS  Physician Specialty                S  OMOP4821941
# ...

# %%
syn[syn['language_concept_id'] == 4180186]
# Out:
#          concept_id                               concept_synonym_name  \
# 0           3019950  CELL MARKERS; Immune globulin A; Immunoglobuli...
# 1           3019950                          Lymphs IgA/lymph NFr Spec
# 2           3019951  Finding; Findings; nursing; Ordinal; Point in ...
# 3           3019955                          pCO2 Bld Postductal TcCo2
# 4           3019955  Bld Postductal; Bld.foot; BldA.foot; Blood; Ca...
# ...             ...                                                ...
# 5153378     3019924                          E chaffeensis Ab Ser-aCnc
# 5153380     3019929                          Androsterone 24h Ur-sRate
# 5153381     3019929  1 day; 24 hours; 24HR; Androster; Chemistry; Q...
# 5153383     3019939  Arm; c; Contr; Contra; Contrst; Document; Elbo...
# 5153384     3019939                           MR Elbow-L WO+W contr IV
#
#          language_concept_id
# 0                    4180186
# 1                    4180186
# ...

# %%
syn = syn[syn['language_concept_id'].isin([4180186, 4175771])]
syn
# Out:
#          concept_id                               concept_synonym_name  \
# 0           3019950  CELL MARKERS; Immune globulin A; Immunoglobuli...
# 1           3019950                          Lymphs IgA/lymph NFr Spec
# 2           3019951  Finding; Findings; nursing; Ordinal; Point in ...
# 3           3019955                          pCO2 Bld Postductal TcCo2
# 4           3019955  Bld Postductal; Bld.foot; BldA.foot; Blood; Ca...
# ...             ...                                                ...
# 5153378     3019924                          E chaffeensis Ab Ser-aCnc
# 5153380     3019929                          Androsterone 24h Ur-sRate
# 5153381     3019929  1 day; 24 hours; 24HR; Androster; Chemistry; Q...
# 5153383     3019939  Arm; c; Contr; Contra; Contrst; Document; Elbo...
# 5153384     3019939                           MR Elbow-L WO+W contr IV
#
#          language_concept_id
# 0                    4180186
# 1                    4180186
# ...

# %%
syn.to_csv('/home/work/skku/hyo/MapOMOP/data/CONCEPT_SYNONYM.csv', sep='\t', index=False)
